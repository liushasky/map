# %% [markdown]
# # HUMDATA

# %%
### Automatically download data
import urllib
url = 'https://data.humdata.org/dataset/3b39f85b-12cf-49cd-aa00-ee3ac04ce61f/resource/235f892e-beea-4d90-8af3-19baf12ea5b9/download/hti_polbndl_rd_cnigs.xlsx'
urllib.request.urlretrieve(url, "hti_polbndl_rd_cnigs.xlsx")

# %%
! pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.7-py2.py3-none-any.whl (243 kB)
#      |████████████████████████████████| 243 kB 2.9 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.0.1.tar.gz (8.4 kB)
# Building wheels for collected packages: et-xmlfile
#   Building wheel for et-xmlfile (setup.py) ... done
#   Created wheel for et-xmlfile: filename=et_xmlfile-1.0.1-py3-none-any.whl size=8913 sha256=f69863aaa12b92d631e1e01b56377654513eeaf95b63488a5b8469775db23098
#   Stored in directory: /home/jovyan/.cache/pip/wheels/bb/9b/ff/8fdf015c95a57224237bf88fbb9e45237cbe8177213bc13732
# Successfully built et-xmlfile
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.0.1 openpyxl-3.0.7

# %%
import geopandas as gpd
humdata = gpd.read_file('hti_polbndl_rd_CNIGS/hti_polbndl_rd_cnigs.shp')

# %%
humdata.crs
# Out:
# <Projected CRS: EPSG:32618>
# Name: WGS 84 / UTM zone 18N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: World - N hemisphere - 78°W to 72°W - by country
# - bounds: (-78.0, 0.0, -72.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 18N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
humdata = humdata[~pd.isnull(humdata['geometry'])]

# %%
humdata = humdata.to_crs(epsg=4326)

# %%
humdata.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
humdata
# Out:
#              cod_tronc cod_route cod_urbain nom_off nom_sec  \
# 0                 None      None       None    None    None
# 1                 None      None       None    None    None
# 2                 None      None       None    None    None
# 3                 None      None       None    None    None
# 4                 None      None       None    None    None
# ...                ...       ...        ...     ...     ...
# 78143             None      None       None    None    None
# 78144             None      None       None    None    None
# 78145  TN0000000002530      None       None    None    None
# 78146  TN0000000002530      None       None    None    None
# 78147             None      None       None    None    None
#
#                                                 geometry
# 0      LINESTRING (-72.64167 19.24389, -72.64202 19.2...
# 1      LINESTRING (-72.69068 19.27519, -72.69071 19.2...
# 2      LINESTRING (-72.69128 19.27525, -72.69121 19.2...
# 3      LINESTRING (-72.69270 19.26339, -72.69279 19.2...
# 4      LINESTRING (-72.69128 19.27525, -72.69134 19.2...
# ...                                                  ...
# 78143  LINESTRING (-73.40199 18.39383, -73.40182 18.3...
# 78144  LINESTRING (-72.51490 19.26116, -72.51418 19.2...
# 78145  LINESTRING (-72.51340 19.26137, -72.51336 19.2...
# 78146  LINESTRING (-72.51396 19.26496, -72.51398 19.2...
# 78147  LINESTRING (-72.67269 19.28420, -72.67393 19.2...
#
# [78095 rows x 6 columns]

# %% [markdown]
# # OSM

# %%
import osmnx as ox
import networkx as nx
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
from pyproj import CRS
# %matplotlib inline
import seaborn as sns
import folium

# %%
place_name = "Haiti"
hti_graph = ox.graph_from_place(place_name, network_type='drive')
edges = ox.graph_to_gdfs(hti_graph, nodes=False, edges=True)
edges.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
edges.reset_index(inplace=True)
edges.drop(['u','v','key'],axis=1, inplace=True)

# %%
edges
# Out:
#         level_0   index                  osmid        name       highway  \
# 0             0       0               49224232    PS Hotel  unclassified
# 1             1       1              446049875         NaN      tertiary
# 2             2       2  [446049875, 30018812]  Rue Capois      tertiary
# 3             3       3               48454003         NaN      tertiary
# 4             4       4               48454003         NaN      tertiary
# ...         ...     ...                    ...         ...           ...
# 152582   152582  152582              722021562         NaN   residential
# 152583   152583  152583              722021561         NaN   residential
# 152584   152584  152584              722021561         NaN   residential
# 152585   152585  152585              722021562         NaN   residential
# 152586   152586  152586              722021562         NaN   residential
#
#         oneway   length                                           geometry  \
# 0        False  234.299  LINESTRING (-73.91427 18.08219, -73.91437 18.0...
# 1        False  796.887  LINESTRING (-73.91427 18.08219, -73.91392 18.0...
# 2        False  399.810  LINESTRING (-73.91427 18.08219, -73.91436 18.0...
# 3        False   85.521  LINESTRING (-73.88924 18.19991, -73.88843 18.1...
# 4        False   65.781  LINESTRING (-73.88924 18.19991, -73.88986 18.1...
# ...        ...      ...                                                ...
# 152582   False   84.446  LINESTRING (-74.45454 18.40630, -74.45442 18.4...
# 152583   False  111.067  LINESTRING (-74.45555 18.40658, -74.45545 18.4...
# 152584   False  111.067  LINESTRING (-74.45458 18.40696, -74.45509 18.4...
# 152585   False   84.446  LINESTRING (-74.45458 18.40696, -74.45444 18.4...
# 152586   False   56.695  LINESTRING (-74.45458 18.40696, -74.45467 18.4...
#
#         ref bridge maxspeed tunnel lanes junction access width service  \
# 0       NaN    NaN      NaN    NaN   NaN      NaN    NaN   NaN     NaN
# 1       NaN    NaN      NaN    NaN   NaN      NaN    NaN   NaN     NaN
# 2       NaN    NaN      NaN    NaN   NaN      NaN    NaN   NaN     NaN
# 3       NaN    NaN      NaN    NaN   NaN      NaN    NaN   NaN     NaN
# 4       NaN    NaN      NaN    NaN   NaN      NaN    NaN   NaN     NaN
# ...     ...    ...      ...    ...   ...      ...    ...   ...     ...
# 152582  NaN    NaN      NaN    NaN   NaN      NaN    NaN   NaN     NaN
# 152583  NaN    NaN      NaN    NaN   NaN      NaN    NaN   NaN     NaN
# 152584  NaN    NaN      NaN    NaN   NaN      NaN    NaN   NaN     NaN
# 152585  NaN    NaN      NaN    NaN   NaN      NaN    NaN   NaN     NaN
# 152586  NaN    NaN      NaN    NaN   NaN      NaN    NaN   NaN     NaN
#
#        est_width
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 152582       NaN
# 152583       NaN
# 152584       NaN
# 152585       NaN
# 152586       NaN
#
# [152587 rows x 18 columns]

# %%
for c in ['osmid','name','highway','oneway','length']:
    edges[c] = edges[c].map(lambda x: x[0] if type(x)==list else '')

# %%
edges[['osmid','name','geometry','highway','oneway','length']].to_file('hti_osm_road.shp', index=False)
